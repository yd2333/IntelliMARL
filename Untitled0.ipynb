# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/Shareddrives/CSCI5525/SNmodel
# !python3 /content/drive/Shareddrives/CSCI5525/SNmodel/train.py
# Out:
# /content/drive/Shareddrives/CSCI5525/SNmodel
# Epoch 0: reward -55.0
# Epoch 1: reward -51.0
# Epoch 2: reward -38.0
# Epoch 3: reward -49.0
# Epoch 4: reward -45.0
# Epoch 5: reward -30.0
# Epoch 6: reward -31.0
# Epoch 7: reward -22.0
# Epoch 8: reward -26.0
# Epoch 9: reward -34.0
# Epoch 10: reward -25.0
# Epoch 11: reward -16.0
# Epoch 12: reward -20.0
# Epoch 13: reward -13.0
# Epoch 14: reward -14.0
# Epoch 15: reward -21.0
# Epoch 16: reward -23.0
# Epoch 17: reward -12.0
# Epoch 18: reward -21.0
# Epoch 19: reward -9.0
# Epoch 20: reward -16.0
# Epoch 21: reward -21.0
# Epoch 22: reward -19.0
# Epoch 23: reward -13.0
# Epoch 24: reward -25.0
# Epoch 25: reward -15.0
# Epoch 26: reward -12.0
# Epoch 27: reward -18.0
# Epoch 28: reward -15.0
# Epoch 29: reward -14.0
# Epoch 30: reward -16.0
# Epoch 31: reward -7.0
# Epoch 32: reward -20.0
# Epoch 33: reward -14.0
# Epoch 34: reward -22.0
# Epoch 35: reward -13.0
# Epoch 36: reward -7.0
# Epoch 37: reward -17.0
# ...
